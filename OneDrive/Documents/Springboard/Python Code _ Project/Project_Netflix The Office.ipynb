# %%
years = [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
durations = [103, 101, 99, 100, 100, 95, 95, 96, 93, 90]
movie_dict = dict(zip(years, durations))
print(movie_dict)
# Out:
# {2011: 103, 2012: 101, 2013: 99, 2014: 100, 2015: 100, 2016: 95, 2017: 95, 2018: 96, 2019: 93, 2020: 90}

# %%
import pandas as pd

# %%
durations_df = pd.DataFrame(movie_dict, index=['durations_df'])
print(durations_df)
# Out:
#               2011  2012  2013  2014  2015  2016  2017  2018  2019  2020
# durations_df   103   101    99   100   100    95    95    96    93    90

# %%
import matplotlib.pyplot as plt
fig = plt.figure()

# Draw a line plot of release_years and durations
plt.plot(years,durations)

# Create a title
plt.title("Netflix Movie Durations 2011-2020")

# Show the plot
plt.show()

# %%
# Read in the CSV as a DataFrame
netflix_df =read.csv("datasets/netflix_data.csv")

# Print the first five rows of the DataFrame
print("netflix_df",[5])

##   show_id     type  title           director  \
0      s1  TV Show     3%                NaN   
1      s2    Movie   7:19  Jorge Michel Grau   
2      s3    Movie  23:59       Gilbert Chan   
3      s4    Movie      9        Shane Acker   
4      s5    Movie     21     Robert Luketic
# Out:
#   Cell In[58], line 8
#     0      s1  TV Show     3%                NaN
#            ^
# SyntaxError: invalid syntax

# %%
# Subset the DataFrame for type "Movie"
netflix_df_movies_only =netflix_df[netflix_df["type"]=="Movie"]

# Select only the columns of interest
netflix_movies_col_subset = netflix_df_movies_only[["title", "country", "genre", "release_year", "duration"]]

# Print the first five rows of the new DataFrame
print(netflix_movies_col_subset.head())
#   title        country          genre  release_year  duration
#1   7:19         Mexico         Dramas          2016        93
#2  23:59      Singapore  Horror Movies          2011        78
#3      9  United States         Action          2009        80
#4     21  United States         Dramas          2008       123
#6    122          Egypt  Horror Movies          2019        95

# %%
# Create a figure and increase the figure size
fig = plt.figure(figsize=(12,8))

# Create a scatter plot of duration versus year
plt.scatter(netflix_movies_col_subset["release_year"], netflix_movies_col_subset["duration"])

# Create a title
plt.title("Movie Duration by Year of Release")

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 5
#       2 fig = plt.figure(figsize=(12,8))
#       4 # Create a scatter plot of duration versus year
# ----> 5 plt.scatter(netflix_movies_col_subset["release_year"], netflix_movies_col_subset["duration"])
#       7 # Create a title
#       8 plt.title("Movie Duration by Year of Release")
#
# NameError: name 'netflix_movies_col_subset' is not defined

# %%
# Filter for durations shorter than 60 minutes
short_movies =netflix_movies_col_subset[netflix_movies_col_subset["duration"] <60]

# Print the first 20 rows of short_movies
short_movies.head(20)

# %%
# Set the figure style and initalize a new figure
plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(12,8))

# Create a scatter plot of duration versus release_year
plt.scatter(netflix_movies_col_subset["release_year"], netflix_movies_col_subset["duration"],'colors')

# Create a title and axis labels
plt.title("Movie duration by year of release")
plt.xlabel("Release year")
plt.ylabel("Duration(min)")

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 6
#       3 fig = plt.figure(figsize=(12,8))
#       5 # Create a scatter plot of duration versus release_year
# ----> 6 plt.scatter(netflix_movies_col_subset["release_year"], netflix_movies_col_subset["duration"],'colors')
#       8 # Create a title and axis labels
#       9 plt.title("Movie duration by year of release")
#
# NameError: name 'netflix_movies_col_subset' is not defined

# %%
# Set the figure style and initalize a new figure
plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(12,8))

# Create a scatter plot of duration versus release_year
plt.scatter(netflix_movies_col_subset["release_year"], netflix_movies_col_subset["duration"],c=colors)

# Create a title and axis labels
plt.title("Movie duration by year of release")
plt.xlabel("Release year")
plt.ylabel("Duration(min)")

# Show the plot
plt.show()

# %%
x = 3

while x > 1:
    print(‘hello’)

    x = x - 1
# Out:
#   Cell In[67], line 4
#     print(‘hello’)
#           ^
# SyntaxError: invalid character '‘' (U+2018)
